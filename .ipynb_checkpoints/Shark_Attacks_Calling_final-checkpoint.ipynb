# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %load_ext autoreload
# %autoreload 2

import Shark_Attack_functions_final

Shark_Attack_functions_final.run_all()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 6
#       2 get_ipython().run_line_magic('autoreload', '2')
#       4 import Shark_Attack_functions_final
# ----> 6 Shark_Attack_functions_final.run_all()
#
# File ~/Documents/GitHub/data-cleaning-pandas-/Shark_Attack_functions_final.py:18, in run_all()
#      16 def run_all():
#      17     global shark_attacks_dropped
# ---> 18     shark_attacks_df = pd.read_excel("GSAF5.xls")
#      19     shark_attacks_df
#      20     #dropping unnesseccary columns and assigning it to a new dataname
#
# File ~/anaconda3/lib/python3.11/site-packages/pandas/util/_decorators.py:211, in deprecate_kwarg.<locals>._deprecate_kwarg.<locals>.wrapper(*args, **kwargs)
#     209     else:
#     210         kwargs[new_arg_name] = new_arg_value
# --> 211 return func(*args, **kwargs)
#
# ...

# %%
cleaned_data = Shark_Attack_functions_final.run_all()


Shark_Attack_functions_final.make_a_sexy_dataframe(cleaned_data)
# Out:
#             country  shark attack count
# 0               usa                2409
# 1         australia                1340
# 2      south africa                 567
# 3  papua new guinea                 147
# 4           bahamas                 124
# 5            brazil                 118
# 6       new zealand                 112
# 7            mexico                  89
# 8            france                  68
# 9             italy                  63

# %%
Shark_Attack_functions_final.make_a_sexy_plot(cleaned_data)
# Out:
# Text(29.222222222222214, 0.5, 'SHARK ATTACK COUNT')

# %%
top10_countries = Shark_Attack_functions_final.make_a_sexy_dataframe(cleaned_data)

# %%
Shark_Attack_functions_final.make_another_sexy_plot(top10_countries)
# Out:
# Text(33.722222222222214, 0.5, 'SHARK ATTACKS PER 100 KM COASTLINE')
